# %%
import os
import pymysql
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup

host = os.getenv('localhost')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')

conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="root",
    passwd="",
    db="recommender_system",
    charset='utf8mb4')

# %%
#PARA BUSCAR UNA PELICULA POR SU CODIGO

def searchMovieIfExist( key ):
    
    sql  = "SELECT * FROM tittle_basics WHERE tconst='%s'"%(key)
   
    df = pd.read_sql_query( sql, conn )
    return df.tail(10)

# %%
#searchMovieIfExist("tt0000001")

# %%
#OBTIENE TODA LAS LISTAS GURDADAS
def getList(name):
    sql  = "SELECT * FROM lists WHERE name like '%s'"%(name)
   
    df = pd.read_sql_query( sql, conn )
    return df

# %%
#getList("nombre prueba")

# %%
def insertList(name, link, metadata):
    
    with conn.cursor() as cursor:
        # CREA UNA NUEVA FILA
        sql = "INSERT INTO lists ( name, link, metadata ) VALUES ( %s, %s, %s )"
        cursor.execute( sql,( name, link, metadata ) )
        
        #GUARDAMOS LOS CAMBIOS
        conn.commit()

# %%
#insertList("nombre prueba", "link prueba", "meta prueba")

# %%
def getNIterations(number):
    nIteration = 1
    div= number%100
    print ("Resto: ",div)
    if number >= 100:
        
        nIteration = int(number/100)+1
        print("N iteration-> ", nIteration)
        
    return nIteration

# %%
def getInfoLists( lists ):
    
    resultList = []
    
    #RECORRO LAS LISTAS Y SACO LA INFORMACIÓN
    for list in lists:
        collectorList = []
        #OBTENGO EL NOMBRE DE LA LISTA
        infoList = list.find( "div" , {"class": "list_name"} )
        nameList = infoList.find( "a" )    
        collectorList.append(nameList.text)


        #OBTENGO EL LINK DE LA LISTA

        linkList = infoList.find( 'a', href = True) 
        collectorList.append(linkList['href'])
        


        #OBTENGO LA METADATA DE LA LISTA
        metadataList = list.find( "div" , {"class": "list_meta"} )
        collectorList.append(metadataList.text)

        resultList.append(collectorList)
        
    return resultList

# %%
def formatUrlPage( url, number ):
    url+="?page=%d"%number #url formatada para rec
    return  url

# %%
def downloadExcel( urlDomain ,urlIdList ):
    
    stringExport = "/export?ref_=ttls_otexp"
    url = urlDomain+urlIdList+stringExport
    idList = urlIdList.split("/",2)[-1]
    print("idlist: "+ idList)
    print("Download: "+url)
    fileName= idList+".csv"
    r = requests.get(url, allow_redirects=True)
    
    data = pd.read_csv(r.content) 
    print(data)
    open(fileName, 'wb').write(r.content)

# %%
def getListImdb(url):
    
    countPage = 1 #indice de la página que debe iterar al menos una vez
    url = formatUrlPage( url, countPage )
    
    r = requests.get(url)
    html_content = r.text
    soup = BeautifulSoup(html_content, 'lxml')
    
    nIterationsText=  soup.find("span",{"class":"list-pagination-total-elements"})
    nIterations = getNIterations( int( nIterationsText.text ) )    
    countIterations = 0
    
    resultList = None 
    countNot200 = 0
    while countIterations < nIterations:
        time.sleep(1)
        print("Url: " + url)
        print("CountNot200: ", countNot200)      
            
        if r.status_code == 200:
            countNot200 = 0
            html_content = r.text
            soup = BeautifulSoup(html_content, 'lxml')
            #OBTENGO TODAS LAS LISTAS
            lists = soup.findAll("div", {"class": "list-preview"})
            resultList = getInfoLists( lists )
            countPage+=1
            url=url.split('?',1)[0]
            url = formatUrlPage( url, countPage )
            r = requests.get(url)
            countIterations+=1

        elif countNot200 >= 3:
            
            return -200
        else:
            countNot200 += 1

    return resultList

# %%
#URL DE LA LISTA A BUSCAR
urlDomain='https://www.imdb.com'
urlList="/lists/tt0074486"
url=urlDomain+urlList

#SACAMOS EL CODIGO DE LA PELICULA
tconst=url.split('/',4)[-1]
tconst=tconst.split('?',1)[0]

#limpiamos parametros get
urlSplit= url.split('?',1)[0]

#OBTENEMOS LAS LISTAS
listas = getListImdb(  url) 

if isinstance( listas, list):
    
    for lista in listas:
        
        time.sleep(1)
        downloadExcel( urlDomain, lista[1] )    
     #insertList(lista[0], lista[1], lista[2])
else:
    print( "Problema al descargar la data: ", listas)
# Out:
# Resto:  98
# N iteration->  10
# Url: https://www.imdb.com/lists/tt0074486?page=1
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=2
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=3
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=4
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=5
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=6
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=7
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=8
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=9
# CountNot200:  0
# Url: https://www.imdb.com/lists/tt0074486?page=10
# CountNot200:  0
# idlist: ls057480442
# Download: https://www.imdb.com/list/ls057480442/export?ref_=ttls_otexp
# idlist: ls000431013
# Download: https://www.imdb.com/list/ls000431013/export?ref_=ttls_otexp
# idlist: ls055014651
# Download: https://www.imdb.com/list/ls055014651/export?ref_=ttls_otexp
# idlist: ls055111477
# Download: https://www.imdb.com/list/ls055111477/export?ref_=ttls_otexp
# idlist: ls057665411
# Download: https://www.imdb.com/list/ls057665411/export?ref_=ttls_otexp
# idlist: ls057658802
# Download: https://www.imdb.com/list/ls057658802/export?ref_=ttls_otexp
# idlist: ls001821418
# Download: https://www.imdb.com/list/ls001821418/export?ref_=ttls_otexp
# idlist: ls003091952
# Download: https://www.imdb.com/list/ls003091952/export?ref_=ttls_otexp
# idlist: ls057793254
# Download: https://www.imdb.com/list/ls057793254/export?ref_=ttls_otexp
# idlist: ls057021300
# Download: https://www.imdb.com/list/ls057021300/export?ref_=ttls_otexp
# idlist: ls055178644
# Download: https://www.imdb.com/list/ls055178644/export?ref_=ttls_otexp
# idlist: ls005193104
# Download: https://www.imdb.com/list/ls005193104/export?ref_=ttls_otexp
# idlist: ls050566299
# Download: https://www.imdb.com/list/ls050566299/export?ref_=ttls_otexp
# idlist: ls050844652
# Download: https://www.imdb.com/list/ls050844652/export?ref_=ttls_otexp
# idlist: ls008052875
# Download: https://www.imdb.com/list/ls008052875/export?ref_=ttls_otexp
# idlist: ls008255400
# Download: https://www.imdb.com/list/ls008255400/export?ref_=ttls_otexp
# idlist: ls000277918
# Download: https://www.imdb.com/list/ls000277918/export?ref_=ttls_otexp
# idlist: ls050731913
# Download: https://www.imdb.com/list/ls050731913/export?ref_=ttls_otexp
# idlist: ls008843239
# Download: https://www.imdb.com/list/ls008843239/export?ref_=ttls_otexp
# idlist: ls009767937
# Download: https://www.imdb.com/list/ls009767937/export?ref_=ttls_otexp
# idlist: ls050091615
# Download: https://www.imdb.com/list/ls050091615/export?ref_=ttls_otexp
# idlist: ls050519525
# Download: https://www.imdb.com/list/ls050519525/export?ref_=ttls_otexp
# idlist: ls008620203
# Download: https://www.imdb.com/list/ls008620203/export?ref_=ttls_otexp
# idlist: ls006929800
# Download: https://www.imdb.com/list/ls006929800/export?ref_=ttls_otexp
# idlist: ls008453971
# Download: https://www.imdb.com/list/ls008453971/export?ref_=ttls_otexp
# idlist: ls004499934
# Download: https://www.imdb.com/list/ls004499934/export?ref_=ttls_otexp
# idlist: ls008302668
# Download: https://www.imdb.com/list/ls008302668/export?ref_=ttls_otexp
# idlist: ls008089655
# Download: https://www.imdb.com/list/ls008089655/export?ref_=ttls_otexp
# idlist: ls009821182
# Download: https://www.imdb.com/list/ls009821182/export?ref_=ttls_otexp
# idlist: ls004251396
# Download: https://www.imdb.com/list/ls004251396/export?ref_=ttls_otexp
# idlist: ls009289476
# Download: https://www.imdb.com/list/ls009289476/export?ref_=ttls_otexp
# idlist: ls009391865
# Download: https://www.imdb.com/list/ls009391865/export?ref_=ttls_otexp
# idlist: ls009365476
# Download: https://www.imdb.com/list/ls009365476/export?ref_=ttls_otexp
# idlist: ls009169826
# Download: https://www.imdb.com/list/ls009169826/export?ref_=ttls_otexp
# idlist: ls003062281
# Download: https://www.imdb.com/list/ls003062281/export?ref_=ttls_otexp
# idlist: ls009753382
# Download: https://www.imdb.com/list/ls009753382/export?ref_=ttls_otexp
# idlist: ls003129601
# Download: https://www.imdb.com/list/ls003129601/export?ref_=ttls_otexp
# idlist: ls000070612
# Download: https://www.imdb.com/list/ls000070612/export?ref_=ttls_otexp
# idlist: ls004930998
# Download: https://www.imdb.com/list/ls004930998/export?ref_=ttls_otexp
# idlist: ls004137976
# Download: https://www.imdb.com/list/ls004137976/export?ref_=ttls_otexp
# idlist: ls004209103
# Download: https://www.imdb.com/list/ls004209103/export?ref_=ttls_otexp
# idlist: ls002284938
# Download: https://www.imdb.com/list/ls002284938/export?ref_=ttls_otexp
# idlist: ls004195697
# Download: https://www.imdb.com/list/ls004195697/export?ref_=ttls_otexp
# idlist: ls004562281
# Download: https://www.imdb.com/list/ls004562281/export?ref_=ttls_otexp
# idlist: ls005796570
# Download: https://www.imdb.com/list/ls005796570/export?ref_=ttls_otexp
# idlist: ls002232524
# Download: https://www.imdb.com/list/ls002232524/export?ref_=ttls_otexp
# idlist: ls002618759
# Download: https://www.imdb.com/list/ls002618759/export?ref_=ttls_otexp
# idlist: ls003241223
# Download: https://www.imdb.com/list/ls003241223/export?ref_=ttls_otexp
# idlist: ls002789177
# Download: https://www.imdb.com/list/ls002789177/export?ref_=ttls_otexp
# idlist: ls002585913
# Download: https://www.imdb.com/list/ls002585913/export?ref_=ttls_otexp
# idlist: ls003850228
# Download: https://www.imdb.com/list/ls003850228/export?ref_=ttls_otexp
# idlist: ls000049001
# Download: https://www.imdb.com/list/ls000049001/export?ref_=ttls_otexp
# idlist: ls006825481
# Download: https://www.imdb.com/list/ls006825481/export?ref_=ttls_otexp
# idlist: ls000792621
# Download: https://www.imdb.com/list/ls000792621/export?ref_=ttls_otexp
# idlist: ls006221123
# Download: https://www.imdb.com/list/ls006221123/export?ref_=ttls_otexp
# idlist: ls006168300
# Download: https://www.imdb.com/list/ls006168300/export?ref_=ttls_otexp
# idlist: ls006150809
# Download: https://www.imdb.com/list/ls006150809/export?ref_=ttls_otexp
# idlist: ls003921412
# Download: https://www.imdb.com/list/ls003921412/export?ref_=ttls_otexp
# idlist: ls006560140
# Download: https://www.imdb.com/list/ls006560140/export?ref_=ttls_otexp
# idlist: ls006077257
# Download: https://www.imdb.com/list/ls006077257/export?ref_=ttls_otexp
# idlist: ls006008696
# Download: https://www.imdb.com/list/ls006008696/export?ref_=ttls_otexp
# idlist: ls003846091
# Download: https://www.imdb.com/list/ls003846091/export?ref_=ttls_otexp
# idlist: ls000996958
# Download: https://www.imdb.com/list/ls000996958/export?ref_=ttls_otexp
# idlist: ls003963569
# Download: https://www.imdb.com/list/ls003963569/export?ref_=ttls_otexp
# idlist: ls003931603
# Download: https://www.imdb.com/list/ls003931603/export?ref_=ttls_otexp
# idlist: ls003280314
# Download: https://www.imdb.com/list/ls003280314/export?ref_=ttls_otexp
# idlist: ls003465820
# Download: https://www.imdb.com/list/ls003465820/export?ref_=ttls_otexp
# idlist: ls003211542
# Download: https://www.imdb.com/list/ls003211542/export?ref_=ttls_otexp
# idlist: ls000983233
# Download: https://www.imdb.com/list/ls000983233/export?ref_=ttls_otexp
# idlist: ls003205947
# Download: https://www.imdb.com/list/ls003205947/export?ref_=ttls_otexp
# idlist: ls003365221
# Download: https://www.imdb.com/list/ls003365221/export?ref_=ttls_otexp
# idlist: ls003308331
# Download: https://www.imdb.com/list/ls003308331/export?ref_=ttls_otexp
# idlist: ls003303468
# Download: https://www.imdb.com/list/ls003303468/export?ref_=ttls_otexp
# idlist: ls005307285
# Download: https://www.imdb.com/list/ls005307285/export?ref_=ttls_otexp
# idlist: ls005335087
# Download: https://www.imdb.com/list/ls005335087/export?ref_=ttls_otexp
# idlist: ls000817371
# Download: https://www.imdb.com/list/ls000817371/export?ref_=ttls_otexp
# idlist: ls000983894
# Download: https://www.imdb.com/list/ls000983894/export?ref_=ttls_otexp
# idlist: ls000944231
# Download: https://www.imdb.com/list/ls000944231/export?ref_=ttls_otexp
# idlist: ls000928466
# Download: https://www.imdb.com/list/ls000928466/export?ref_=ttls_otexp
# idlist: ls000971396
# Download: https://www.imdb.com/list/ls000971396/export?ref_=ttls_otexp
# idlist: ls000693433
# Download: https://www.imdb.com/list/ls000693433/export?ref_=ttls_otexp
# idlist: ls000162887
# Download: https://www.imdb.com/list/ls000162887/export?ref_=ttls_otexp
# idlist: ls000347540
# Download: https://www.imdb.com/list/ls000347540/export?ref_=ttls_otexp
# idlist: ls000330506
# Download: https://www.imdb.com/list/ls000330506/export?ref_=ttls_otexp
# idlist: ls000748721
# Download: https://www.imdb.com/list/ls000748721/export?ref_=ttls_otexp
# idlist: ls000544225
# Download: https://www.imdb.com/list/ls000544225/export?ref_=ttls_otexp
# idlist: ls000035135
# Download: https://www.imdb.com/list/ls000035135/export?ref_=ttls_otexp
# idlist: ls000047099
# Download: https://www.imdb.com/list/ls000047099/export?ref_=ttls_otexp
# idlist: ls000047624
# Download: https://www.imdb.com/list/ls000047624/export?ref_=ttls_otexp
# idlist: ls000068802
# Download: https://www.imdb.com/list/ls000068802/export?ref_=ttls_otexp
# idlist: ls000029128
# Download: https://www.imdb.com/list/ls000029128/export?ref_=ttls_otexp
# idlist: ls000021057
# Download: https://www.imdb.com/list/ls000021057/export?ref_=ttls_otexp
# idlist: ls000036252
# Download: https://www.imdb.com/list/ls000036252/export?ref_=ttls_otexp
# idlist: ls000079956
# Download: https://www.imdb.com/list/ls000079956/export?ref_=ttls_otexp
# idlist: ls000072795
# Download: https://www.imdb.com/list/ls000072795/export?ref_=ttls_otexp
# idlist: ls000054436
# Download: https://www.imdb.com/list/ls000054436/export?ref_=ttls_otexp
# idlist: ls000054658
# Download: https://www.imdb.com/list/ls000054658/export?ref_=ttls_otexp
# idlist: ls000057670
# Download: https://www.imdb.com/list/ls000057670/export?ref_=ttls_otexp
